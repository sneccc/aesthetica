# %%
directory = r"C:\Users\Daniel\CodingProjects\aesthetica\data\normalized_3d_test"

# %%
#Data to CSV
# !python data_to_csv.py -i {directory}

# %%
#Dataset to Embeddings
# !python dataset_to_embeddings.py -i {directory}

# %%
directory = r"C:\Users\Daniel\CodingProjects\aesthetica\data\normalized_3d_test"
#Train Model
from train_model import start_training

start_training(root_folder=directory, database_file="image_classifier_data.csv", train_from="embeddings", clip_models=[("hf-hub:timm", "ViT-SO400M-14-SigLIP-384")])

# %%
#Test Model
from test_model import predict_score
directory = r"C:\Users\Daniel\CodingProjects\aesthetica\data\normalized_3d_test"

predict_score(root_folder=directory, clip_models=[("hf-hub:timm", "ViT-SO400M-14-SigLIP-384")])
